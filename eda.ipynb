# %% [markdown]
# # Nordcast - Ingestion data

# %%
import pandas as pd

df3 = pd.read_csv("data/smhi-opendata_19_71380_199604_200603.csv", sep=";", skiprows=11)
df2 = pd.read_csv("data/smhi-opendata_19_71380_199604_200603.csv", sep=";", skiprows=11)
df1 = pd.read_csv("data/smhi-opendata_19_71380_201602_202601.csv", sep=";", skiprows=11)

# %% [markdown]
# ## Control of ingested data

# %%
df1.head()
# Out:
#   Från Datum Tid (UTC) Till Datum Tid (UTC) Representativt dygn  \
# 0  2016-02-01 18:00:01  2016-02-02 18:00:00          2016-02-02
# 1  2016-02-02 18:00:01  2016-02-03 18:00:00          2016-02-03
# 2  2016-02-03 18:00:01  2016-02-04 18:00:00          2016-02-04
# 3  2016-02-04 18:00:01  2016-02-05 18:00:00          2016-02-05
# 4  2016-02-05 18:00:01  2016-02-06 18:00:00          2016-02-06
#
#    Lufttemperatur Kvalitet  Lufttemperatur.1 Kvalitet.1  Unnamed: 7  \
# 0             4.1        Y               7.3          Y         NaN
# 1             2.6        Y               6.0          Y         NaN
# 2             2.6        Y               4.2          Y         NaN
# 3             2.0        Y               3.5          Y         NaN
# 4             2.7        Y               5.0          Y         NaN
#
#    Tidsutsnitt:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3652 entries, 0 to 3651
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Från Datum Tid (UTC)  3652 non-null   object
#  1   Till Datum Tid (UTC)  3652 non-null   object
#  2   Representativt dygn   3652 non-null   object
#  3   Lufttemperatur        3652 non-null   float64
#  4   Kvalitet              3652 non-null   object
#  5   Lufttemperatur.1      3652 non-null   float64
#  6   Kvalitet.1            3652 non-null   object
#  7   Unnamed: 7            0 non-null      float64
#  8   Tidsutsnitt:          0 non-null      float64
# dtypes: float64(4), object(5)
# memory usage: 256.9+ KB

# %%
df2.head()
# Out:
#   Från Datum Tid (UTC) Till Datum Tid (UTC) Representativt dygn  \
# 0  1996-04-01 18:00:01  1996-04-02 18:00:00          1996-04-02
# 1  1996-04-02 18:00:01  1996-04-03 18:00:00          1996-04-03
# 2  1996-04-03 18:00:01  1996-04-04 18:00:00          1996-04-04
# 3  1996-04-04 18:00:01  1996-04-05 18:00:00          1996-04-05
# 4  1996-04-05 18:00:01  1996-04-06 18:00:00          1996-04-06
#
#    Lufttemperatur Kvalitet  Lufttemperatur.1 Kvalitet.1  Unnamed: 7  \
# 0            -4.0        G               2.0          G         NaN
# 1             1.0        G               4.4          G         NaN
# 2             2.0        G               4.0          G         NaN
# 3             0.8        G               3.4          G         NaN
# 4             0.2        G               9.1          G         NaN
#
#    Tidsutsnitt:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Från Datum Tid (UTC)  608 non-null    object
#  1   Till Datum Tid (UTC)  608 non-null    object
#  2   Representativt dygn   608 non-null    object
#  3   Lufttemperatur        608 non-null    float64
#  4   Kvalitet              608 non-null    object
#  5   Lufttemperatur.1      608 non-null    float64
#  6   Kvalitet.1            608 non-null    object
#  7   Unnamed: 7            0 non-null      float64
#  8   Tidsutsnitt:          0 non-null      float64
# dtypes: float64(4), object(5)
# memory usage: 42.9+ KB

# %%
df3.head()
# Out:
#   Från Datum Tid (UTC) Till Datum Tid (UTC) Representativt dygn  \
# 0  1996-04-01 18:00:01  1996-04-02 18:00:00          1996-04-02
# 1  1996-04-02 18:00:01  1996-04-03 18:00:00          1996-04-03
# 2  1996-04-03 18:00:01  1996-04-04 18:00:00          1996-04-04
# 3  1996-04-04 18:00:01  1996-04-05 18:00:00          1996-04-05
# 4  1996-04-05 18:00:01  1996-04-06 18:00:00          1996-04-06
#
#    Lufttemperatur Kvalitet  Lufttemperatur.1 Kvalitet.1  Unnamed: 7  \
# 0            -4.0        G               2.0          G         NaN
# 1             1.0        G               4.4          G         NaN
# 2             2.0        G               4.0          G         NaN
# 3             0.8        G               3.4          G         NaN
# 4             0.2        G               9.1          G         NaN
#
#    Tidsutsnitt:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Från Datum Tid (UTC)  608 non-null    object
#  1   Till Datum Tid (UTC)  608 non-null    object
#  2   Representativt dygn   608 non-null    object
#  3   Lufttemperatur        608 non-null    float64
#  4   Kvalitet              608 non-null    object
#  5   Lufttemperatur.1      608 non-null    float64
#  6   Kvalitet.1            608 non-null    object
#  7   Unnamed: 7            0 non-null      float64
#  8   Tidsutsnitt:          0 non-null      float64
# dtypes: float64(4), object(5)
# memory usage: 42.9+ KB

# %% [markdown]
# ### Concat all dataframes

# %%
all_df = pd.concat([df1, df2, df3], ignore_index=True)

all_df.head()
# Out:
#   Från Datum Tid (UTC) Till Datum Tid (UTC) Representativt dygn  \
# 0  2016-02-01 18:00:01  2016-02-02 18:00:00          2016-02-02
# 1  2016-02-02 18:00:01  2016-02-03 18:00:00          2016-02-03
# 2  2016-02-03 18:00:01  2016-02-04 18:00:00          2016-02-04
# 3  2016-02-04 18:00:01  2016-02-05 18:00:00          2016-02-05
# 4  2016-02-05 18:00:01  2016-02-06 18:00:00          2016-02-06
#
#    Lufttemperatur Kvalitet  Lufttemperatur.1 Kvalitet.1  Unnamed: 7  \
# 0             4.1        Y               7.3          Y         NaN
# 1             2.6        Y               6.0          Y         NaN
# 2             2.6        Y               4.2          Y         NaN
# 3             2.0        Y               3.5          Y         NaN
# 4             2.7        Y               5.0          Y         NaN
#
#    Tidsutsnitt:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4868 entries, 0 to 4867
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Från Datum Tid (UTC)  4868 non-null   object
#  1   Till Datum Tid (UTC)  4868 non-null   object
#  2   Representativt dygn   4868 non-null   object
#  3   Lufttemperatur        4868 non-null   float64
#  4   Kvalitet              4868 non-null   object
#  5   Lufttemperatur.1      4868 non-null   float64
#  6   Kvalitet.1            4868 non-null   object
#  7   Unnamed: 7            0 non-null      float64
#  8   Tidsutsnitt:          0 non-null      float64
# dtypes: float64(4), object(5)
# memory usage: 342.4+ KB

# %% [markdown]
# ## Exploring columns

# %%
all_df["Unnamed: 7"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
all_df["Tidsutsnitt:"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# ## Dropping empty columns

# %%
all_df = all_df.dropna(axis=1, how="all")

all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4868 entries, 0 to 4867
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Från Datum Tid (UTC)  4868 non-null   object
#  1   Till Datum Tid (UTC)  4868 non-null   object
#  2   Representativt dygn   4868 non-null   object
#  3   Lufttemperatur        4868 non-null   float64
#  4   Kvalitet              4868 non-null   object
#  5   Lufttemperatur.1      4868 non-null   float64
#  6   Kvalitet.1            4868 non-null   object
# dtypes: float64(2), object(5)
# memory usage: 266.3+ KB
